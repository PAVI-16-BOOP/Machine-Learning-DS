# %% [markdown]
# ### KNN MODEL

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv("Classified Data",index_col=0)
df
# Out:
#           WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0    0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1    0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2    0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3    1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4    1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  1.010953  1.034006  0.853116  0.622460  1.036610  0.586240  0.746811
# 996  0.575529  0.955786  0.941835  0.792882  1.414277  1.269540  1.055928
# 997  1.135470  0.982462  0.781905  0.916738  0.901031  0.884738  0.386802
# 998  1.084894  0.861769  0.407158  0.665696  1.608612  0.943859  0.855806
# 999  0.837460  0.961184  0.417006  0.799784  0.934399  0.424762  0.778234
#
#           PJF       HQE       NXJ  TARGET CLASS
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(df.drop("TARGET CLASS",axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df.drop("TARGET CLASS",axis=1))
scaled_features
# Out:
# array([[-0.12354188,  0.18590747, -0.91343069, ..., -1.48236813,
#         -0.9497194 , -0.64331425],
#        [-1.08483602, -0.43034845, -1.02531333, ..., -0.20224031,
#         -1.82805088,  0.63675862],
#        [-0.78870217,  0.33931821,  0.30151137, ...,  0.28570652,
#         -0.68249379, -0.37784986],
#        ...,
#        [ 0.64177714, -0.51308341, -0.17920486, ..., -2.36249443,
#         -0.81426092,  0.11159651],
#        [ 0.46707241, -0.98278576, -1.46519359, ..., -0.03677699,
#          0.40602453, -0.85567   ],
#        [-0.38765353, -0.59589427, -1.4313981 , ..., -0.56778932,
#          0.3369971 ,  0.01034996]])

# %%
dfff=pd.DataFrame(scaled_features,columns=df.columns[:-1])
dfff
# Out:
#           WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0   -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375 -0.798951
# 1   -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706 -1.129797
# 2   -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156  2.599818
# 3    0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220  1.750208
# 4    1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773  0.596782
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.211653 -0.312490  0.065163 -0.259834  0.017567 -1.395721 -0.849486
# 996 -1.292453 -0.616901  0.369613  0.482648  1.569891  1.273495  0.362784
# 997  0.641777 -0.513083 -0.179205  1.022255 -0.539703 -0.229680 -2.261339
# 998  0.467072 -0.982786 -1.465194 -0.071465  2.368666  0.001269 -0.422041
# 999 -0.387654 -0.595894 -1.431398  0.512722 -0.402552 -2.026512 -0.726253
#
#           PJF       HQE       NXJ
# 0   -1.482368 -0.949719 -0.643314
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=dfff
y=df["TARGET CLASS"]

x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn= KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(x_test)

# %%
from sklearn.metrics import classification_report , confusion_matrix

# %%
print(confusion_matrix(pred , y_test))
# Out:
# [[151  15]
#  [  8 126]]

# %%
print(classification_report(pred , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       166
#            1       0.89      0.94      0.92       134
#
#     accuracy                           0.92       300
#    macro avg       0.92      0.92      0.92       300
# weighted avg       0.92      0.92      0.92       300

# %% [markdown]
# ### ELBOW Method to choose a correct K-Value

# %%
error_rate=[]

for i in range(1,40):
    knn= KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    pred_i = knn.predict(x_test)
    error_rate.append(np.mean( pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color="blue",ls="--",marker="o",markerfacecolor="red")
plt.title("Error Rate v/s Values")
plt.xlabel("Model number")
plt.ylabel("Error Rate")
plt.show()

# %%
# a better model with a superior K-Value

knn = KNeighborsClassifier(n_neighbors=38)
knn.fit(x_train,y_train)
pred_38 = knn.predict(x_test)
print(confusion_matrix(pred_38 , y_test))
print("\n")
print(classification_report(pred_38 , y_test))
# Out:
# [[153   7]
#  [  6 134]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       160
#            1       0.95      0.96      0.95       140
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.96      0.96       300
# weighted avg       0.96      0.96      0.96       300
